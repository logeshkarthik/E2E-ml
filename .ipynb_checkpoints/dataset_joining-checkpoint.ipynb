# %%
import pyspark
from azure.storage.blob import BlobServiceClient
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
from pyspark.sql.types import StructType, StructField, StringType, FloatType, DoubleType, IntegerType, LongType
from pyspark.sql.functions import count,lit, when,col,expr, udf, avg,to_date,broadcast,regexp_replace,last,lpad,concat_ws,date_format,year,month
from pyspark.sql import Window
import sys
from pyspark import SparkContext
import pyspark.sql 

import pandas as pd
import matplotlib.pyplot as plt



STORAGEACCOUNTURL = "https://trainingbatchaccount.blob.core.windows.net"
STORAGEACCOUNTKEY = "2QPPHsAtQ8/fh33VE7wqg/ZaeJoxdq/pnevAEmCh0n32tC5eXa8dTEEwMHdD9Ff5k1/wVh97aubqgKzQSwOLnQ=="
CONTAINERNAME = "datasets"
# HOSPITALIZATION = "economy.csv"
# INDEX = "index.csv"


spark = SparkSession.builder.appName('azure').getOrCreate()
spark.conf.set(
        "fs.azure.account.key.trainingbatchaccount.blob.core.windows.net",
        STORAGEACCOUNTKEY
    
)

#-----------------------------Schema for hospitalizations dataset-------------------------------

hospitalizations_schema = StructType([StructField("date",StringType(), True),\
    StructField("location_key",StringType(), True),\
    StructField("new_hospitalized_patients", IntegerType(), True),\
    StructField("cumulative_hospitalized_patients", IntegerType(), True),\
    StructField("current_hospitalized_patients", IntegerType(), True),\
    StructField("new_intensive_care_patients", IntegerType(), True),\
    StructField("cumulative_intensive_care_patients", IntegerType(), True),\
    StructField("current_intensive_care_patients", IntegerType(), True),\
    StructField("new_ventilator_patients", StringType(), True),\
    StructField("cumulative_ventilator_patients", StringType(), True),\
    StructField("current_ventilator_patients", IntegerType(), True)])

#-----------------------------Schema for vaccination dataset-------------------------------  

vaccination_schema = StructType([StructField("date",StringType(), True),\
    StructField("location_key",StringType(), True),\
    StructField("new_persons_vaccinated", IntegerType(), True),\
    StructField("cumulative_persons_vaccinated", IntegerType(), True),\
    StructField("new_persons_fully_vaccinated", IntegerType(), True),\
    StructField("cumulative_persons_fully_vaccinated", IntegerType(), True),\
    StructField("new_vaccine_doses_administered", IntegerType(), True),\
    StructField("cumulative_vaccine_doses_administered", LongType(), True),\
    StructField("new_persons_vaccinated_pfizer", IntegerType(), True),\
    StructField("cumulative_persons_vaccinated_pfizer", IntegerType(), True),\
    StructField("new_persons_fully_vaccinated_pfizer", IntegerType(), True),\
    StructField("cumulative_persons_fully_vaccinated_pfizer", IntegerType(), True),\
    StructField("new_vaccine_doses_administered_pfizer", IntegerType(), True),\
    StructField("cumulative_vaccine_doses_administered_pfizer", IntegerType(), True),\
    StructField("new_persons_vaccinated_moderna", IntegerType(), True),\
    StructField("cumulative_persons_vaccinated_moderna", IntegerType(), True),\
    StructField("new_persons_fully_vaccinated_moderna", IntegerType(), True),\
    StructField("cumulative_persons_fully_vaccinated_moderna", IntegerType(), True),\
    StructField("new_vaccine_doses_administered_moderna", IntegerType(), True),\
    StructField("cumulative_vaccine_doses_administered_moderna", IntegerType(), True),\
    StructField("new_persons_vaccinated_janssen", IntegerType(), True),\
    StructField("cumulative_persons_vaccinated_janssen", IntegerType(), True),\
    StructField("new_persons_fully_vaccinated_janssen", IntegerType(), True),\
    StructField("cumulative_persons_fully_vaccinated_janssen", IntegerType(), True),\
    StructField("new_vaccine_doses_administered_janssen", IntegerType(), True),\
    StructField("cumulative_vaccine_doses_administered_janssen", IntegerType(), True),\
    StructField("new_persons_vaccinated_sinovac", IntegerType(), True),\
    StructField("total_persons_vaccinated_sinovac", IntegerType(), True),\
    StructField("new_persons_fully_vaccinated_sinovac", StringType(), True),\
    StructField("total_persons_fully_vaccinated_sinovac", StringType(), True),\
    StructField("new_vaccine_doses_administered_sinovac", StringType(), True),\
    StructField("total_vaccine_doses_administered_sinovac", StringType(), True)])
  #-----------------------------Schema for epidemiology dataset-------------------------------

epidemiology_schema = StructType([StructField("date",StringType(), True),\
    StructField("location_key",StringType(), True),\
    StructField("new_confirmed", IntegerType(), True),\
    StructField("new_deceased", IntegerType(), True),\
    StructField("new_recovered", IntegerType(), True),\
    StructField("new_tested", IntegerType(), True),\
    StructField("cumulative_confirmed", IntegerType(), True),\
    StructField("cumulative_deceased", IntegerType(), True),\
    StructField("cumulative_recovered", IntegerType(), True),\
    StructField("cumulative_tested", IntegerType(), True)])

  

hosp_df = spark.read.format('csv').option('header',True).schema(hospitalizations_schema).load("wasbs://datasets@trainingbatchaccount.blob.core.windows.net/hospitalizations.csv")
vacc_df = spark.read.format('csv').option('header',True).schema(vaccination_schema).load("wasbs://datasets@trainingbatchaccount.blob.core.windows.net/vaccinations.csv")
epi_df = spark.read.format('csv').option('header',True).schema(epidemiology_schema).load("wasbs://datasets@trainingbatchaccount.blob.core.windows.net/epidemiology.csv")

# %%
# to find shape of dataframe 
def sparkShape(dataFrame):
    return (dataFrame.count(), len(dataFrame.columns))
pyspark.sql.dataframe.DataFrame.shape = sparkShape

spark.conf.set('spark.sql.repl.eagerEval.enabled', True)

# %%
from pyspark.sql import SparkSession
import functools

# %%
#---------------------------------Opening hospitalization dataset and cleaning it----------------

hosp_df = hosp_df.withColumn('Date',to_date(hosp_df['date'],'dd-MM-yyyy'))
#fill empty values with zero
hosp_df = hosp_df.fillna(value = 0, subset = ['new_hospitalized_patients','current_hospitalized_patients','current_intensive_care_patients','new_ventilator_patients','cumulative_ventilator_patients','current_ventilator_patients'])
#drop unwanted column
hosp_df = hosp_df.drop('cumulative_ventilator_patients','new_ventilator_patients')
hosp_df = hosp_df.where((hosp_df.location_key == 'AR')&(hosp_df.Date >= '2021-01-01')&(hosp_df.Date <= '2021-12-31'))

# %%
hosp_df.shape()
# Out:
# (365, 9)

# %%
hosp_df.tail(5)
# Out:
# [Row(Date=datetime.date(2021, 12, 27), location_key='AR', new_hospitalized_patients=359, cumulative_hospitalized_patients=435445, current_hospitalized_patients=0, new_intensive_care_patients=60, cumulative_intensive_care_patients=76343, current_intensive_care_patients=0, current_ventilator_patients=0),
#  Row(Date=datetime.date(2021, 12, 28), location_key='AR', new_hospitalized_patients=396, cumulative_hospitalized_patients=435841, current_hospitalized_patients=0, new_intensive_care_patients=63, cumulative_intensive_care_patients=76406, current_intensive_care_patients=0, current_ventilator_patients=0),
#  Row(Date=datetime.date(2021, 12, 29), location_key='AR', new_hospitalized_patients=368, cumulative_hospitalized_patients=436209, current_hospitalized_patients=0, new_intensive_care_patients=50, cumulative_intensive_care_patients=76456, current_intensive_care_patients=0, current_ventilator_patients=0),
#  Row(Date=datetime.date(2021, 12, 30), location_key='AR', new_hospitalized_patients=336, cumulative_hospitalized_patients=436545, current_hospitalized_patients=0, new_intensive_care_patients=61, cumulative_intensive_care_patients=76517, current_intensive_care_patients=0, current_ventilator_patients=0),
#  Row(Date=datetime.date(2021, 12, 31), location_key='AR', new_hospitalized_patients=284, cumulative_hospitalized_patients=436829, current_hospitalized_patients=0, new_intensive_care_patients=54, cumulative_intensive_care_patients=76571, current_intensive_care_patients=0, current_ventilator_patients=0)]

# %%
 #---------------------------------Opening epidemology dataset and cleaning it----------------
    
# epi_df = epi_df.withColumn('date',to_date(epi_df['date'],format='yyyy-mm-dd'))
# epi_df = epi_df.na.fill(value=0)


#correct date format
epi_df = epi_df.withColumn('Date',to_date(epi_df['date'],format='yyyy-MM-dd'))
epi_df = epi_df.na.fill(value=0)
# vacc_df = vacc_df.withColumn('Date_1',(vacc_df['Date']))
# vacc_df = vacc_df.withColumn("Date_string",vacc_df.Date.cast(StringType()))
epi_df = epi_df.where((epi_df.location_key == 'AR')&(epi_df.Date >= '2021-01-01')&(epi_df.Date <= '2021-12-31'))
epi_df = epi_df.drop('location_key')

# %%
epi_df.tail(5)
# Out:
# [Row(Date=datetime.date(2021, 12, 27), new_confirmed=37421, new_deceased=31, new_recovered=0, new_tested=101951, cumulative_confirmed=5544836, cumulative_deceased=117462, cumulative_recovered=0, cumulative_tested=20840125),
#  Row(Date=datetime.date(2021, 12, 28), new_confirmed=50165, new_deceased=34, new_recovered=0, new_tested=127203, cumulative_confirmed=5595001, cumulative_deceased=117496, cumulative_recovered=0, cumulative_tested=20967328),
#  Row(Date=datetime.date(2021, 12, 29), new_confirmed=59711, new_deceased=33, new_recovered=0, new_tested=149689, cumulative_confirmed=5654712, cumulative_deceased=117529, cumulative_recovered=0, cumulative_tested=21117017),
#  Row(Date=datetime.date(2021, 12, 30), new_confirmed=63734, new_deceased=45, new_recovered=0, new_tested=162734, cumulative_confirmed=5718446, cumulative_deceased=117574, cumulative_recovered=0, cumulative_tested=21279751),
#  Row(Date=datetime.date(2021, 12, 31), new_confirmed=45805, new_deceased=26, new_recovered=0, new_tested=105720, cumulative_confirmed=5764251, cumulative_deceased=117600, cumulative_recovered=0, cumulative_tested=21385471)]

# %%
epi_df.printSchema()
# Out:
# root
#  |-- Date: date (nullable = true)
#  |-- new_confirmed: integer (nullable = true)
#  |-- new_deceased: integer (nullable = true)
#  |-- new_recovered: integer (nullable = true)
#  |-- new_tested: integer (nullable = true)
#  |-- cumulative_confirmed: integer (nullable = true)
#  |-- cumulative_deceased: integer (nullable = true)
#  |-- cumulative_recovered: integer (nullable = true)
#  |-- cumulative_tested: integer (nullable = true)

# %%
 #---------------------------------Opening vaccination dataset and cleaning it----------------
    
#selecting needed columns only
vacc_df = vacc_df.select("date","location_key","new_persons_vaccinated","cumulative_persons_vaccinated","new_persons_fully_vaccinated","cumulative_persons_fully_vaccinated","new_vaccine_doses_administered","cumulative_vaccine_doses_administered")

#Drop rows if all the values are null
vacc_df = vacc_df.na.drop(subset=["new_persons_vaccinated","cumulative_persons_vaccinated","new_persons_fully_vaccinated","cumulative_persons_fully_vaccinated","new_vaccine_doses_administered","cumulative_vaccine_doses_administered"] ,how="all")

#fill cumulative value with previous field value (Forward Fill)
vacc_df = vacc_df.withColumn("cumulative_persons_vaccinated", last('cumulative_persons_vaccinated', True).over(Window.partitionBy('location_key').rowsBetween(-sys.maxsize, 0)))
vacc_df = vacc_df.withColumn("cumulative_persons_fully_vaccinated",last('cumulative_persons_fully_vaccinated', True).over(Window.partitionBy('location_key').rowsBetween(-sys.maxsize, 0)))
vacc_df = vacc_df.withColumn("cumulative_vaccine_doses_administered",last('cumulative_vaccine_doses_administered', True).over(Window.partitionBy('location_key').rowsBetween(-sys.maxsize, 0)))

#replace null with zero
vacc_df = vacc_df.na.fill(value=0)

#correct date format
vacc_df = vacc_df.withColumn('Date',to_date(vacc_df['Date'],format='yyyy-MM-dd'))
# vacc_df = vacc_df.withColumn('Date_1',(vacc_df['Date']))
# vacc_df = vacc_df.withColumn("Date_string",vacc_df.Date.cast(StringType()))
vacc_df = vacc_df.where((vacc_df.location_key == 'AR')&(vacc_df.Date >= '2021-01-01')&(vacc_df.Date <= '2021-12-31'))
#  hosp_df.where((hosp_df.location_key == 'AR')&(hosp_df.Date >= '2021-01-01')&(hosp_df.Date <= '2021-12-31'))
vacc_df = vacc_df.drop('location_key')

# %%
vacc_df.tail(5)
# Out:
# [Row(Date=datetime.date(2021, 12, 27), new_persons_vaccinated=9720, cumulative_persons_vaccinated=5428856, new_persons_fully_vaccinated=18189, cumulative_persons_fully_vaccinated=4640500, new_vaccine_doses_administered=27909, cumulative_vaccine_doses_administered=10069356),
#  Row(Date=datetime.date(2021, 12, 28), new_persons_vaccinated=9912, cumulative_persons_vaccinated=5438768, new_persons_fully_vaccinated=16785, cumulative_persons_fully_vaccinated=4657285, new_vaccine_doses_administered=26697, cumulative_vaccine_doses_administered=10096053),
#  Row(Date=datetime.date(2021, 12, 29), new_persons_vaccinated=10075, cumulative_persons_vaccinated=5448843, new_persons_fully_vaccinated=16203, cumulative_persons_fully_vaccinated=4673488, new_vaccine_doses_administered=26278, cumulative_vaccine_doses_administered=10122331),
#  Row(Date=datetime.date(2021, 12, 30), new_persons_vaccinated=8293, cumulative_persons_vaccinated=5457136, new_persons_fully_vaccinated=13452, cumulative_persons_fully_vaccinated=4686940, new_vaccine_doses_administered=21745, cumulative_vaccine_doses_administered=10144076),
#  Row(Date=datetime.date(2021, 12, 31), new_persons_vaccinated=518, cumulative_persons_vaccinated=5457654, new_persons_fully_vaccinated=1069, cumulative_persons_fully_vaccinated=4688009, new_vaccine_doses_administered=1587, cumulative_vaccine_doses_administered=10145663)]

# %%
hosp_df.printSchema()
vacc_df.printSchema()
epi_df.printSchema()
# Out:
# root
#  |-- Date: date (nullable = true)
#  |-- location_key: string (nullable = true)
#  |-- new_hospitalized_patients: integer (nullable = true)
#  |-- cumulative_hospitalized_patients: integer (nullable = true)
#  |-- current_hospitalized_patients: integer (nullable = true)
#  |-- new_intensive_care_patients: integer (nullable = true)
#  |-- cumulative_intensive_care_patients: integer (nullable = true)
#  |-- current_intensive_care_patients: integer (nullable = true)
#  |-- current_ventilator_patients: integer (nullable = true)
#
# root
#  |-- Date: date (nullable = true)
#  |-- new_persons_vaccinated: integer (nullable = true)
#  |-- cumulative_persons_vaccinated: integer (nullable = true)
#  |-- new_persons_fully_vaccinated: integer (nullable = true)
#  |-- cumulative_persons_fully_vaccinated: integer (nullable = true)
#  |-- new_vaccine_doses_administered: integer (nullable = true)
#  |-- cumulative_vaccine_doses_administered: long (nullable = true)
#
# root
#  |-- Date: date (nullable = true)
#  |-- new_confirmed: integer (nullable = true)
#  |-- new_deceased: integer (nullable = true)
#  |-- new_recovered: integer (nullable = true)
#  |-- new_tested: integer (nullable = true)
#  |-- cumulative_confirmed: integer (nullable = true)
#  |-- cumulative_deceased: integer (nullable = true)
#  |-- cumulative_recovered: integer (nullable = true)
#  |-- cumulative_tested: integer (nullable = true)

# %%
# joining 
# hosp_df
# vacc_df

df_hosp_vacc = hosp_df.join(vacc_df,['Date'],"inner")

df_hosp_vacc_epi = df_hosp_vacc.join(epi_df,['Date'],"inner")
# df_hosp_vacc_epi = df_hosp_vacc_epi.sort_values(by='Date')
# df_hosp_vacc = hosp_df.join(vacc_df,hosp_df.Date ==  vacc_df.Date,"inner")


# df_hosp_vacc_epi.show(truncate=False)

# %%
df_hosp_vacc_epi.shape()
# Out:
# (365, 23)

# %%
df_hosp_vacc_epi.tail(20)
# Out:
# [Row(Date=datetime.date(2021, 10, 7), location_key='AR', new_hospitalized_patients=226, cumulative_hospitalized_patients=416651, current_hospitalized_patients=0, new_intensive_care_patients=24, cumulative_intensive_care_patients=73861, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=11780, cumulative_persons_vaccinated=4323152, new_persons_fully_vaccinated=23895, cumulative_persons_fully_vaccinated=3425012, new_vaccine_doses_administered=35675, cumulative_vaccine_doses_administered=7748164, new_confirmed=861, new_deceased=20, new_recovered=0, new_tested=33669, cumulative_confirmed=5286341, cumulative_deceased=116331, cumulative_recovered=0, cumulative_tested=18224953),
#  Row(Date=datetime.date(2021, 11, 6), location_key='AR', new_hospitalized_patients=144, cumulative_hospitalized_patients=424019, current_hospitalized_patients=0, new_intensive_care_patients=15, cumulative_intensive_care_patients=74733, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=8601, cumulative_persons_vaccinated=5065760, new_persons_fully_vaccinated=11162, cumulative_persons_fully_vaccinated=3856507, new_vaccine_doses_administered=19763, cumulative_vaccine_doses_administered=8922267, new_confirmed=849, new_deceased=8, new_recovered=0, new_tested=19327, cumulative_confirmed=5316567, cumulative_deceased=116695, cumulative_recovered=0, cumulative_tested=19122568),
#  Row(Date=datetime.date(2021, 9, 8), location_key='AR', new_hospitalized_patients=410, cumulative_hospitalized_patients=407955, current_hospitalized_patients=0, new_intensive_care_patients=60, cumulative_intensive_care_patients=72788, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=8134, cumulative_persons_vaccinated=4113139, new_persons_fully_vaccinated=44761, cumulative_persons_fully_vaccinated=2571726, new_vaccine_doses_administered=52895, cumulative_vaccine_doses_administered=6684865, new_confirmed=2529, new_deceased=54, new_recovered=0, new_tested=43126, cumulative_confirmed=5246156, cumulative_deceased=115241, cumulative_recovered=0, cumulative_tested=17169025),
#  Row(Date=datetime.date(2021, 12, 17), location_key='AR', new_hospitalized_patients=184, cumulative_hospitalized_patients=433113, current_hospitalized_patients=0, new_intensive_care_patients=38, cumulative_intensive_care_patients=75971, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=6297, cumulative_persons_vaccinated=5386311, new_persons_fully_vaccinated=12908, cumulative_persons_fully_vaccinated=4551909, new_vaccine_doses_administered=19205, cumulative_vaccine_doses_administered=9938220, new_confirmed=5965, new_deceased=19, new_recovered=0, new_tested=46102, cumulative_confirmed=5405954, cumulative_deceased=117251, cumulative_recovered=0, cumulative_tested=20306790),
#  Row(Date=datetime.date(2021, 1, 20), location_key='AR', new_hospitalized_patients=606, cumulative_hospitalized_patients=245004, current_hospitalized_patients=0, new_intensive_care_patients=130, cumulative_intensive_care_patients=39422, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=849, cumulative_persons_vaccinated=35319, new_persons_fully_vaccinated=1936, cumulative_persons_fully_vaccinated=2689, new_vaccine_doses_administered=2785, cumulative_vaccine_doses_administered=38008, new_confirmed=11375, new_deceased=194, new_recovered=0, new_tested=45357, cumulative_confirmed=1872304, cumulative_deceased=49679, cumulative_recovered=0, cumulative_tested=5105396),
#  Row(Date=datetime.date(2021, 1, 28), location_key='AR', new_hospitalized_patients=501, cumulative_hospitalized_patients=249330, current_hospitalized_patients=0, new_intensive_care_patients=108, cumulative_intensive_care_patients=40324, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=229, cumulative_persons_vaccinated=39475, new_persons_fully_vaccinated=2062, cumulative_persons_fully_vaccinated=9958, new_vaccine_doses_administered=2291, cumulative_vaccine_doses_administered=49433, new_confirmed=9264, new_deceased=168, new_recovered=0, new_tested=40371, cumulative_confirmed=1942603, cumulative_deceased=51182, cumulative_recovered=0, cumulative_tested=5406570),
#  Row(Date=datetime.date(2021, 6, 16), location_key='AR', new_hospitalized_patients=933, cumulative_hospitalized_patients=353554, current_hospitalized_patients=0, new_intensive_care_patients=206, cumulative_intensive_care_patients=62448, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=30311, cumulative_persons_vaccinated=1988040, new_persons_fully_vaccinated=10102, cumulative_persons_fully_vaccinated=523912, new_vaccine_doses_administered=40413, cumulative_vaccine_doses_administered=2511952, new_confirmed=23050, new_deceased=523, new_recovered=0, new_tested=67936, cumulative_confirmed=4287120, cumulative_deceased=94397, cumulative_recovered=0, cumulative_tested=12573170),
#  Row(Date=datetime.date(2021, 8, 9), location_key='AR', new_hospitalized_patients=617, cumulative_hospitalized_patients=393795, current_hospitalized_patients=0, new_intensive_care_patients=107, cumulative_intensive_care_patients=70491, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=15820, cumulative_persons_vaccinated=3809174, new_persons_fully_vaccinated=41222, cumulative_persons_fully_vaccinated=1316351, new_vaccine_doses_administered=57042, cumulative_vaccine_doses_administered=5125525, new_confirmed=12207, new_deceased=191, new_recovered=0, new_tested=65330, cumulative_confirmed=5086242, cumulative_deceased=111637, cumulative_recovered=0, cumulative_tested=15600352),
#  Row(Date=datetime.date(2021, 8, 18), location_key='AR', new_hospitalized_patients=621, cumulative_hospitalized_patients=398710, current_hospitalized_patients=0, new_intensive_care_patients=102, cumulative_intensive_care_patients=71358, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=14791, cumulative_persons_vaccinated=3905617, new_persons_fully_vaccinated=46561, cumulative_persons_fully_vaccinated=1657862, new_vaccine_doses_administered=61352, cumulative_vaccine_doses_administered=5563479, new_confirmed=8549, new_deceased=145, new_recovered=0, new_tested=67192, cumulative_confirmed=5155698, cumulative_deceased=113144, cumulative_recovered=0, cumulative_tested=16100914),
#  Row(Date=datetime.date(2021, 1, 6), location_key='AR', new_hospitalized_patients=680, cumulative_hospitalized_patients=236754, current_hospitalized_patients=0, new_intensive_care_patients=127, cumulative_intensive_care_patients=37903, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=1451, cumulative_persons_vaccinated=10907, new_persons_fully_vaccinated=0, cumulative_persons_fully_vaccinated=1, new_vaccine_doses_administered=1451, cumulative_vaccine_doses_administered=10908, new_confirmed=14460, new_deceased=131, new_recovered=0, new_tested=48793, cumulative_confirmed=1717975, cumulative_deceased=47293, cumulative_recovered=0, cumulative_tested=4524393),
#  Row(Date=datetime.date(2021, 5, 30), location_key='AR', new_hospitalized_patients=1014, cumulative_hospitalized_patients=334850, current_hospitalized_patients=0, new_intensive_care_patients=271, cumulative_intensive_care_patients=58318, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=15649, cumulative_persons_vaccinated=1382709, new_persons_fully_vaccinated=2346, cumulative_persons_fully_vaccinated=408526, new_vaccine_doses_administered=17995, cumulative_vaccine_doses_administered=1791235, new_confirmed=14677, new_deceased=615, new_recovered=0, new_tested=34584, cumulative_confirmed=3841884, cumulative_deceased=84298, cumulative_recovered=0, cumulative_tested=11428335),
#  Row(Date=datetime.date(2021, 11, 19), location_key='AR', new_hospitalized_patients=176, cumulative_hospitalized_patients=426998, current_hospitalized_patients=0, new_intensive_care_patients=27, cumulative_intensive_care_patients=75101, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=8030, cumulative_persons_vaccinated=5196893, new_persons_fully_vaccinated=34233, cumulative_persons_fully_vaccinated=4110909, new_vaccine_doses_administered=42263, cumulative_vaccine_doses_administered=9307802, new_confirmed=1528, new_deceased=16, new_recovered=0, new_tested=29431, cumulative_confirmed=5333424, cumulative_deceased=116823, cumulative_recovered=0, cumulative_tested=19484919),
#  Row(Date=datetime.date(2021, 2, 4), location_key='AR', new_hospitalized_patients=460, cumulative_hospitalized_patients=252696, current_hospitalized_patients=0, new_intensive_care_patients=95, cumulative_intensive_care_patients=41008, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=1402, cumulative_persons_vaccinated=43545, new_persons_fully_vaccinated=2573, cumulative_persons_fully_vaccinated=24127, new_vaccine_doses_administered=3975, cumulative_vaccine_doses_administered=67672, new_confirmed=8112, new_deceased=165, new_recovered=0, new_tested=40017, cumulative_confirmed=1996462, cumulative_deceased=52290, cumulative_recovered=0, cumulative_tested=5697325),
#  Row(Date=datetime.date(2021, 3, 11), location_key='AR', new_hospitalized_patients=476, cumulative_hospitalized_patients=268309, current_hospitalized_patients=0, new_intensive_care_patients=88, cumulative_intensive_care_patients=43986, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=21317, cumulative_persons_vaccinated=271463, new_persons_fully_vaccinated=4409, cumulative_persons_fully_vaccinated=56363, new_vaccine_doses_administered=25726, cumulative_vaccine_doses_administered=327826, new_confirmed=7918, new_deceased=122, new_recovered=0, new_tested=37609, cumulative_confirmed=2211801, cumulative_deceased=56794, cumulative_recovered=0, cumulative_tested=6935002),
#  Row(Date=datetime.date(2021, 9, 22), location_key='AR', new_hospitalized_patients=303, cumulative_hospitalized_patients=412655, current_hospitalized_patients=0, new_intensive_care_patients=36, cumulative_intensive_care_patients=73379, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=7976, cumulative_persons_vaccinated=4190361, new_persons_fully_vaccinated=38672, cumulative_persons_fully_vaccinated=3051398, new_vaccine_doses_administered=46648, cumulative_vaccine_doses_administered=7241759, new_confirmed=1567, new_deceased=34, new_recovered=0, new_tested=42408, cumulative_confirmed=5270486, cumulative_deceased=115983, cumulative_recovered=0, cumulative_tested=17720630),
#  Row(Date=datetime.date(2021, 6, 15), location_key='AR', new_hospitalized_patients=987, cumulative_hospitalized_patients=352621, current_hospitalized_patients=0, new_intensive_care_patients=218, cumulative_intensive_care_patients=62242, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=24620, cumulative_persons_vaccinated=1957729, new_persons_fully_vaccinated=12164, cumulative_persons_fully_vaccinated=513810, new_vaccine_doses_administered=36784, cumulative_vaccine_doses_administered=2471539, new_confirmed=25076, new_deceased=512, new_recovered=0, new_tested=68828, cumulative_confirmed=4264070, cumulative_deceased=93874, cumulative_recovered=0, cumulative_tested=12505234),
#  Row(Date=datetime.date(2021, 10, 27), location_key='AR', new_hospitalized_patients=262, cumulative_hospitalized_patients=421663, current_hospitalized_patients=0, new_intensive_care_patients=25, cumulative_intensive_care_patients=74459, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=33435, cumulative_persons_vaccinated=4859247, new_persons_fully_vaccinated=13441, cumulative_persons_fully_vaccinated=3713918, new_vaccine_doses_administered=46876, cumulative_vaccine_doses_administered=8573165, new_confirmed=1353, new_deceased=15, new_recovered=0, new_tested=35809, cumulative_confirmed=5305520, cumulative_deceased=116600, cumulative_recovered=0, cumulative_tested=18837171),
#  Row(Date=datetime.date(2021, 4, 10), location_key='AR', new_hospitalized_patients=727, cumulative_hospitalized_patients=285323, current_hospitalized_patients=0, new_intensive_care_patients=169, cumulative_intensive_care_patients=47486, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=12386, cumulative_persons_vaccinated=704068, new_persons_fully_vaccinated=657, cumulative_persons_fully_vaccinated=106135, new_vaccine_doses_administered=13043, cumulative_vaccine_doses_administered=810203, new_confirmed=18328, new_deceased=268, new_recovered=0, new_tested=57505, cumulative_confirmed=2586850, cumulative_deceased=61417, cumulative_recovered=0, cumulative_tested=8292384),
#  Row(Date=datetime.date(2021, 4, 12), location_key='AR', new_hospitalized_patients=919, cumulative_hospitalized_patients=286929, current_hospitalized_patients=0, new_intensive_care_patients=194, cumulative_intensive_care_patients=47817, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=24427, cumulative_persons_vaccinated=734936, new_persons_fully_vaccinated=1252, cumulative_persons_fully_vaccinated=107569, new_vaccine_doses_administered=25679, cumulative_vaccine_doses_administered=842505, new_confirmed=27063, new_deceased=261, new_recovered=0, new_tested=69686, cumulative_confirmed=2625522, cumulative_deceased=61885, cumulative_recovered=0, cumulative_tested=8397690),
#  Row(Date=datetime.date(2021, 5, 13), location_key='AR', new_hospitalized_patients=1050, cumulative_hospitalized_patients=315799, current_hospitalized_patients=0, new_intensive_care_patients=209, cumulative_intensive_care_patients=54057, current_intensive_care_patients=0, current_ventilator_patients=0, new_persons_vaccinated=5200, cumulative_persons_vaccinated=1174106, new_persons_fully_vaccinated=21319, cumulative_persons_fully_vaccinated=268010, new_vaccine_doses_administered=26519, cumulative_vaccine_doses_administered=1442116, new_confirmed=28275, new_deceased=468, new_recovered=0, new_tested=67761, cumulative_confirmed=3334994, cumulative_deceased=75031, cumulative_recovered=0, cumulative_tested=10271298)]

# %%
# df_hosp_vacc_epi = df_hosp_vacc_epi.drop('location_key')

# %%
df_hosp_vacc_epi.toPandas().to_csv("df_hosp_vacc_epi_1.csv")

# %%
# df_hosp_vacc_epi.printSchema()

# %%
df_hosp_vacc_epi=df_hosp_vacc_epi.drop('location_key')


df_hosp_vacc_epi=df_hosp_vacc_epi.toPandas()
# df_hosp_vacc_epi['Date'] = pd.to_datetime(df_hosp_vacc_epi.Date , format = '%Y-%m-%d')

# %%
df_hosp_vacc_epi.dtypes
# Out:
# Date                                     object
# new_hospitalized_patients                 int32
# cumulative_hospitalized_patients          int32
# current_hospitalized_patients             int32
# new_intensive_care_patients               int32
# cumulative_intensive_care_patients        int32
# current_intensive_care_patients           int32
# current_ventilator_patients               int32
# new_persons_vaccinated                    int32
# cumulative_persons_vaccinated             int32
# new_persons_fully_vaccinated              int32
# cumulative_persons_fully_vaccinated       int32
# new_vaccine_doses_administered            int32
# cumulative_vaccine_doses_administered     int64
# new_confirmed                             int32
# new_deceased                              int32
# new_recovered                             int32
# new_tested                                int32
# cumulative_confirmed                      int32
# cumulative_deceased                       int32
# cumulative_recovered                      int32
# cumulative_tested                         int32
# dtype: object

# %%
df_hosp_vacc_epi =df_hosp_vacc_epi[['Date', 'new_hospitalized_patients', 'new_persons_vaccinated', 'new_persons_fully_vaccinated', 'new_confirmed', 'new_deceased', 'new_recovered', 'new_tested']]

# %%
df_hosp_vacc_epi.dtypes
df_hosp_vacc_epi['Date'] = pd.to_datetime(df_hosp_vacc_epi.Date , format = '%Y-%M-%d')
df_hosp_vacc_epi = df_hosp_vacc_epi.sort_values(by='Date')

# %%
# df_hosp_vacc_epi.tail(5)
# print(df_hosp_vacc_epi)
df_hosp_vacc_epi.head(50)
# Out:
#           Date  new_hospitalized_patients  new_persons_vaccinated  \
# 168 2021-01-01                        450                      15
# 297 2021-01-02                        575                     410
# 206 2021-01-03                        504                      52
# 225 2021-01-04                        759                    1465
# 69  2021-01-05                        650                    1514
# 354 2021-01-06                        680                    1451
# 197 2021-01-07                        649                    2483
# 293 2021-01-08                        622                    3818
# 160 2021-01-09                        553                    1420
# 259 2021-01-10                        557                     172
# 288 2021-01-11                        619                    2644
# 298 2021-01-12                        626                    2621
# 311 2021-01-13                        678                    2155
# 308 2021-01-14                        611                    2243
# 273 2021-01-15                        574                    2440
# 226 2021-01-16                        516                     840
# 325 2021-01-17                        486                     143
# 23  2021-01-18                        556                    1438
# 88  2021-01-19                        597                    1146
# 349 2021-01-20                        606                     849
# 214 2021-01-21                        672                     687
# 100 2021-01-22                        524                     731
# 118 2021-01-23                        428                     165
# 98  2021-01-24                        394                      11
# 24  2021-01-25                        622                    1059
# 173 2021-01-26                        606                     717
# 0   2021-01-27                        579                     557
# 350 2021-01-28                        501                     229
# 280 2021-01-29                        529                     197
# 174 2021-01-30                        391                      20
# 248 2021-01-31                        369                       2
# 94  2021-02-01                        526                     279
# 26  2021-02-02                        519                     711
# 290 2021-02-03                        572                    1459
# 357 2021-02-04                        460                    1402
# 82  2021-02-05                        494                    1949
# 101 2021-02-06                        429                     458
# 334 2021-02-07                        399                      68
# 175 2021-02-08                        513                    2262
# 176 2021-02-09                        517                    2022
# 87  2021-02-10                        482                    1570
# 181 2021-02-11                        443                     603
# 277 2021-02-12                        499                     593
# 291 2021-02-13                        383                      56
# 269 2021-02-14                        367                       4
# 17  2021-02-15                        388                     150
# 326 2021-02-16                        390                     106
# 192 2021-02-17                        454                    2528
# 250 2021-02-18                        444                    7236
# 135 2021-02-19                        460                    8183
#
#      new_persons_fully_vaccinated  new_confirmed  new_deceased  new_recovered  \
# 168                             0           2684           140              0
# 297                             0           7766           166              0
# 206                             0           4934           157              0
# 225                             1          13952           157              0
# 69                              0          14083           160              0
# 354                             0          14460           131              0
# 197                             2          13720           160              0
# 293                             2          13931           162              0
# 160                             0           9959           158              0
# 259                             0           5174           165              0
# 288                             1          13076           170              0
# 298                             0          12787           172              0
# 311                             0          13372           155              0
# 308                             0          12129           149              0
# 273                             2          11378           191              0
# 226                             0           8426           174              0
# 325                             1           4950           180              0
# 23                              2          12017           186              0
# 88                            742          12035           170              0
# 349                          1936          11375           194              0
# 214                          1271          10398           219              0
# 100                           526           9963           184              0
# 118                           426           6676           176              0
# 98                             30           3769           192              0
# 24                           1032          10040           184              0
# 173                          1069          10304           191              0
# 0                             853           9885           189              0
# 350                          2062           9264           168              0
# 280                          3090           8714           152              0
# 174                          1148           6380           167              0
# 248                            94           3913           148              0
# 94                           2317           8934           161              0
# 26                           2591           9147           161              0
# 290                          2356           8659           154              0
# 357                          2573           8112           165              0
# 82                           2706           7685           166              0
# 101                          1095           5117           147              0
# 334                           111           2910           158              0
# 175                          1043           7379           120              0
# 176                           805           7758           138              0
# 87                            681           7118           156              0
# 181                          1925           7165           125              0
# 277                          1646           7182           122              0
# 291                           393           4902           148              0
# 269                            19           2716           126              0
# 17                             27           3889           142              0
# 326                            30           3550           105              0
# 192                           712           7887           131              0
# 250                          1527           7857           145              0
# 135                          1030           7480           133              0
#
#      new_tested
# 168        8171
# 297       25659
# 206       21208
# 225       43432
# 69        46793
# 354       48793
# 197       44734
# 293       46347
# 160       37055
# 259       22146
# 288       42942
# 298       44014
# 311       47152
# 308       44300
# 273       48976
# 226       38319
# 325       25656
# 23        45678
# 88        48327
# 349       45357
# 214       43018
# 100       41190
# 118       30822
# 98        21301
# 24        41236
# 173       40841
# 0         42395
# 350       40371
# 280       41637
# 174       36199
# 248       31756
# 94        45965
# 26        49553
# 290       45628
# 357       40017
# 82        39264
# 101       29780
# 334       20789
# 175       41698
# 176       43291
# 87        43321
# 181       40901
# 277       42713
# 291       34019
# 269       22607
# 17        30062
# 326       31743
# 192       46050
# 250       46426
# 135       44341

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = df_hosp_vacc_epi[df_hosp_vacc_epi.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(df_hosp_vacc_epi.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
df_hosp_vacc_epi['Date'] = pd.to_datetime(df_hosp_vacc_epi.Date , format = '%Y-%m-%d')

df_hosp_vacc_epi = df_hosp_vacc_epi.sort_values(by='Date')


data = df_hosp_vacc_epi.drop(['Date'], axis=1)
data.index = df_hosp_vacc_epi.Date

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.varmax import VARMAX
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import grangercausalitytests, adfuller
from tqdm import tqdm_notebook
from itertools import product

# %%
# performing augmented dicky fuller test to check the stationarity of the column new_hospitalized_patients

ad_fuller_result_1 = adfuller(df_hosp_vacc_epi['new_hospitalized_patients'].diff()[1:])

print('new_hospitalized_patients')
print(f'ADF Statistic: {ad_fuller_result_1[0]}')
print(f'p-value: {ad_fuller_result_1[1]}')

print('\n---------------------\n')

ad_fuller_result_2 = adfuller(df_hosp_vacc_epi['new_persons_vaccinated'].diff()[1:])

print('new_persons_vaccinated')
print(f'ADF Statistic: {ad_fuller_result_2[0]}')
print(f'p-value: {ad_fuller_result_2[1]}')
# Out:
# new_hospitalized_patients
# ADF Statistic: -2.9944866405893094
# p-value: 0.03541249643539132
#
# ---------------------
#
# new_persons_vaccinated
# ADF Statistic: -4.9320772786507545
# p-value: 3.019245943485067e-05

# %%
# checking the corelation of the columns using grangercausalitytests


print('new_hospitalized_patients causes new_persons_vaccinated?\n')
print('------------------')
granger_1 = grangercausalitytests(df_hosp_vacc_epi[['new_persons_vaccinated', 'new_hospitalized_patients']], 4)
# 4 specifies the number of lags 
print('\n')
print('new_persons_vaccinated causes new_hospitalized_patients?\n')
print('------------------')
granger_2 = grangercausalitytests(df_hosp_vacc_epi[['new_hospitalized_patients', 'new_persons_vaccinated']], 4)
# Out:
# new_hospitalized_patients causes new_persons_vaccinated?
#
# ------------------
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.8025  , p=0.0291  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=4.8424  , p=0.0278  , df=1
# likelihood ratio test: chi2=4.8105  , p=0.0283  , df=1
# parameter F test:         F=4.8025  , p=0.0291  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.2347  , p=0.0008  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=14.6716 , p=0.0007  , df=2
# likelihood ratio test: chi2=14.3828 , p=0.0008  , df=2
# parameter F test:         F=7.2347  , p=0.0008  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=6.9267  , p=0.0002  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=21.1898 , p=0.0001  , df=3
# likelihood ratio test: chi2=20.5928 , p=0.0001  , df=3
# parameter F test:         F=6.9267  , p=0.0002  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.8799  , p=0.0008  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=20.0188 , p=0.0005  , df=4
# likelihood ratio test: chi2=19.4834 , p=0.0006  , df=4
# parameter F test:         F=4.8799  , p=0.0008  , df_denom=352, df_num=4
#
#
# new_persons_vaccinated causes new_hospitalized_patients?
#
# ------------------
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=24.2125 , p=0.0000  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=24.4137 , p=0.0000  , df=1
# likelihood ratio test: chi2=23.6298 , p=0.0000  , df=1
# parameter F test:         F=24.2125 , p=0.0000  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=13.7146 , p=0.0000  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=27.8123 , p=0.0000  , df=2
# likelihood ratio test: chi2=26.7983 , p=0.0000  , df=2
# parameter F test:         F=13.7146 , p=0.0000  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=16.8490 , p=0.0000  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=51.5438 , p=0.0000  , df=3
# likelihood ratio test: chi2=48.1892 , p=0.0000  , df=3
# parameter F test:         F=16.8490 , p=0.0000  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=10.9528 , p=0.0000  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=44.9315 , p=0.0000  , df=4
# likelihood ratio test: chi2=42.3476 , p=0.0000  , df=4
# parameter F test:         F=10.9528 , p=0.0000  , df_denom=352, df_num=4

# %%
# selcting the 2 columns to be predicted 

df_hosp_vacc_epi = df_hosp_vacc_epi[['new_hospitalized_patients', 'new_persons_vaccinated']]
print(df_hosp_vacc_epi.shape)
# Out:
# (365, 2)

# %%
# splitting the testing data and training data 
train_df=df_hosp_vacc_epi[:-10].astype('float32')
test_df =df_hosp_vacc_epi[-10:].astype('float32')


print(train_df.shape)
print(test_df.shape)
# Out:
# (355, 2)
# (10, 2)

# %%
model = VAR(train_df.diff()[1:])
# Out:
# C:\Users\slogeshkarthik\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# SIC (Schwarz information criterion, aka Bayesian information criterion BIC)
# AIC (Akaike information criterion)
# HQIC (Hannan-Quinn information criterion)


# The aim is to find the model with the lowest value of the selected information criterion. 

# ModelRisk applies these three criteria as a means of ranking each 
# fitted model, whether it be fitting a distribution, a time series model


sorted_order = model.select_order(maxlags=20)
print(sorted_order.summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0        26.47       26.50   3.139e+11       26.48
# 1        26.34       26.41   2.757e+11       26.37
# 2        26.23       26.35   2.467e+11       26.28
# 3        26.16       26.31   2.286e+11       26.22
# 4        26.08       26.29   2.122e+11       26.16
# 5        25.87       26.12   1.717e+11       25.97
# 6        25.60       25.90   1.315e+11       25.72
# 7        25.31      25.65*   9.778e+10       25.44
# 8        25.27       25.66   9.442e+10      25.43*
# 9        25.28       25.71   9.540e+10       25.45
# 10       25.26       25.73   9.302e+10       25.45
# 11       25.28       25.80   9.511e+10       25.49
# 12       25.28       25.85   9.529e+10       25.51
# 13       25.26       25.87   9.330e+10       25.50
# 14      25.21*       25.87  8.854e+10*       25.47
# 15       25.22       25.93   8.998e+10       25.50
# 16       25.23       25.98   9.073e+10       25.53
# 17       25.25       26.05   9.240e+10       25.57
# 18       25.25       26.10   9.270e+10       25.59
# 19       25.27       26.16   9.415e+10       25.62
# 20       25.24       26.18   9.195e+10       25.62
# --------------------------------------------------

# %%
# for varmax model we have to specify the auto regression and the movoing average (4- AR ,0- MA)


var_model = VARMAX(train_df, order=(5,0),enforce_stationarity= True)

# X = X.astype('float32')
# casting to float as the output will be in float and the program unable to convert float to int casting
fitted_model = var_model.fit(disp=False)
print(fitted_model.summary())
# Out:
# C:\Users\slogeshkarthik\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                               Statespace Model Results
# ===================================================================================================================
# Dep. Variable:     ['new_hospitalized_patients', 'new_persons_vaccinated']   No. Observations:                  355
# Model:                                                              VAR(5)   Log Likelihood               -5608.184
#                                                                + intercept   AIC                          11266.369
# Date:                                                     Mon, 11 Apr 2022   BIC                          11363.172
# Time:                                                             14:59:35   HQIC                         11304.879
# Sample:                                                                  0
#                                                                      - 355
# Covariance Type:                                                       opg
# ===================================================================================
# Ljung-Box (L1) (Q):             2.77, 0.06   Jarque-Bera (JB):        21.01, 133.12
# Prob(Q):                        0.10, 0.81   Prob(JB):                   0.00, 0.00
# Heteroskedasticity (H):         0.42, 1.71   Skew:                       0.52, 0.45
# Prob(H) (two-sided):            0.00, 0.00   Kurtosis:                   3.56, 5.86
#                          Results for equation new_hospitalized_patients
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# intercept                        9.9024     12.443      0.796      0.426     -14.486      34.291
# L1.new_hospitalized_patients     0.7218      0.073      9.908      0.000       0.579       0.865
# L1.new_persons_vaccinated       -0.0021      0.001     -2.609      0.009      -0.004      -0.001
# L2.new_hospitalized_patients     0.2164      0.077      2.797      0.005       0.065       0.368
# L2.new_persons_vaccinated       -0.0021      0.001     -2.118      0.034      -0.004      -0.000
# L3.new_hospitalized_patients    -0.1108      0.088     -1.262      0.207      -0.283       0.061
# L3.new_persons_vaccinated        0.0018      0.001      1.651      0.099      -0.000       0.004
# L4.new_hospitalized_patients     0.0068      0.091      0.075      0.940      -0.171       0.185
# L4.new_persons_vaccinated        0.0004      0.001      0.359      0.719      -0.002       0.002
# L5.new_hospitalized_patients     0.1692      0.076      2.214      0.027       0.019       0.319
# L5.new_persons_vaccinated        0.0011      0.001      1.242      0.214      -0.001       0.003
#                           Results for equation new_persons_vaccinated
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# intercept                      561.9693   1131.275      0.497      0.619   -1655.288    2779.227
# L1.new_hospitalized_patients    17.1631      7.137      2.405      0.016       3.175      31.151
# L1.new_persons_vaccinated        0.6431      0.057     11.222      0.000       0.531       0.755
# L2.new_hospitalized_patients     0.6691      7.637      0.088      0.930     -14.298      15.636
# L2.new_persons_vaccinated       -0.0856      0.069     -1.232      0.218      -0.222       0.051
# L3.new_hospitalized_patients    -6.4669      9.034     -0.716      0.474     -24.172      11.239
# L3.new_persons_vaccinated        0.1621      0.085      1.900      0.057      -0.005       0.329
# L4.new_hospitalized_patients    -4.8608      8.637     -0.563      0.574     -21.788      12.067
# L4.new_persons_vaccinated        0.0685      0.094      0.726      0.468      -0.117       0.254
# L5.new_hospitalized_patients    -4.8534      6.573     -0.738      0.460     -17.735       8.029
# L5.new_persons_vaccinated        0.1100      0.068      1.625      0.104      -0.023       0.243
#                                                    Error covariance matrix
# =============================================================================================================================
#                                                                 coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------
# sqrt.var.new_hospitalized_patients                           77.7758      3.173     24.512      0.000      71.557      83.995
# sqrt.cov.new_hospitalized_patients.new_persons_vaccinated  4449.3000    357.244     12.455      0.000    3749.114    5149.486
# sqrt.var.new_persons_vaccinated                            5520.4090    166.645     33.127      0.000    5193.792    5847.026
# =============================================================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.85e+14. Standard errors may be unstable.

# %%
n_forecast = 10
predict = fitted_model.get_prediction(start=len(train_df),end=len(train_df) + n_forecast-1)#start="1989-07-01",end='1999-01-01')

predictions=predict.predicted_mean
# Out:
# C:\Users\slogeshkarthik\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
predictions.columns=['pred_new_hospitalized_patients','pred_new_persons_vaccinated']

predictions
pd.DataFrame({"Actual":test_df['new_hospitalized_patients'],"Prediction":predictions['pred_new_hospitalized_patients']})
# Out:
#      Actual  Prediction
# 49    359.0         NaN
# 99    233.0         NaN
# 109   396.0         NaN
# 128   254.0         NaN
# 134   368.0         NaN
# 156   336.0         NaN
# 188   188.0         NaN
# 229   166.0         NaN
# 257   225.0         NaN
# 306   284.0         NaN
# 355     NaN  253.278260
# 356     NaN  232.358095
# 357     NaN  223.535658
# 358     NaN  237.390688
# 359     NaN  247.851499
# 360     NaN  255.486099
# 361     NaN  254.613336
# 362     NaN  251.001909
# 363     NaN  249.805053
# 364     NaN  251.611712

# %%
test_vs_pred = pd.concat([test_df,predictions],axis=1)

# %%
test_vs_pred.plot(figsize=(12,5))
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error
import math 
from statistics import mean

# 'pred_new_hospitalized_patients','pred_new_persons_vaccinated'

rmse_ulc=math.sqrt(mean_squared_error(predictions['pred_new_hospitalized_patients'],test_df['new_hospitalized_patients']))
print('Mean value of hospitalized_patients is : {}. Root Mean Squared Error is :{}'.format(mean(test_df['new_hospitalized_patients']),rmse_ulc))

rmse_rgnp=math.sqrt(mean_squared_error(predictions['pred_new_persons_vaccinated'],test_df['new_persons_vaccinated']))
print('Mean value of persons_vaccinated is : {}. Root Mean Squared Error is :{}'.format(mean(test_df['new_persons_vaccinated']),rmse_rgnp))



# ['new_hospitalized_patients','new_persons_vaccinated']
# Out:
# Mean value of hospitalized_patients is : 280.9. Root Mean Squared Error is :76.89303298032061
# Mean value of persons_vaccinated is : 5269.8. Root Mean Squared Error is :4309.507077074898
