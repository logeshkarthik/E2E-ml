# %%
# import pandas as pd
# import numpy as np
# import lightgbm as lgb
# import matplotlib.pyplot as plt
# import seaborn as sns
# import warnings
# from sklearn.model_selection import TimeSeriesSplit, GridSearchCV, RandomizedSearchCV
# from sklearn.metrics import make_scorer
# warnings.filterwarnings('ignore')

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns
import lightgbm as lgb
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from sklearn.metrics import mean_absolute_error
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.api as sm
import itertools

import warnings
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 500)
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv("demand_forecasting_datasets/train.csv", parse_dates=["date"])
test = pd.read_csv("demand_forecasting_datasets/test.csv", parse_dates=["date"])
sample_sub = pd.read_csv('demand_forecasting_datasets/sample_submission.csv')
df = pd.concat([train, test], sort=False)

df.head()

# #load dataset
# train = pd.read_csv('../input/demand-forecasting-kernels-only/train.csv', parse_dates=['date'])
# test = pd.read_csv('../input/demand-forecasting-kernels-only/test.csv', parse_dates=['date'])
# df = pd.concat([train, test], sort=False) # veri önişleme için test ve train bir araya getirdim
# df.head()
# Out:
#         date  store  item  sales  id
# 0 2013-01-01      1     1   13.0 NaN
# 1 2013-01-02      1     1   11.0 NaN
# 2 2013-01-03      1     1   14.0 NaN
# 3 2013-01-04      1     1   13.0 NaN
# 4 2013-01-05      1     1   10.0 NaN

# %%
print("Train set:",train.shape)
print("Test set:",test.shape)
# Out:
# Train set: (913000, 4)
# Test set: (45000, 4)

# %%
# combining the training and test dataset
# df = train +test

df.shape
# Out:
# (958000, 5)

# %%
# using quantile function -transform a numeric input variable to have a different data distribution


df.quantile([0, 0.05, 0.25, 0.50, 0.75, 0.95, 0.99, 1]).T
# Out:
#        0.00     0.05      0.25     0.50      0.75      0.95      0.99     1.00
# store   1.0     1.00      3.00      5.5      8.00     10.00     10.00     10.0
# item    1.0     3.00     13.00     25.5     38.00     48.00     50.00     50.0
# sales   0.0    16.00     30.00     47.0     70.00    107.00    135.00    231.0
# id      0.0  2249.95  11249.75  22499.5  33749.25  42749.05  44549.01  44999.0

# %%
df["date"].min()
# Out:
# Timestamp('2013-01-01 00:00:00')

# %%
df["date"].max()
# Out:
# Timestamp('2018-03-31 00:00:00')

# %%
# 25% - The 25% percentile*.
# 50% - The 50% percentile*.
# 75% - The 75% percentile*.
# max - the maximum value.

# *Percentile meaning: how many of the values are less than the given percentile. Read more about percentiles in our Machine Learning Percentile chapter.

df["sales"].describe([0.10, 0.30, 0.50, 0.70, 0.80, 0.90, 0.95, 0.99])
# df["sales"].describe()
# Out:
# count    913000.000000
# mean         52.250287
# std          28.801144
# min           0.000000
# 10%          20.000000
# 30%          33.000000
# 50%          47.000000
# 70%          64.000000
# 80%          76.000000
# 90%          93.000000
# 95%         107.000000
# 99%         135.000000
# max         231.000000
# Name: sales, dtype: float64

# %%
# to find the number of unique values inthe column

df["store"].nunique()
# Out:
# 10

# %%
df["item"].nunique()
# Out:
# 50

# %%
# grouping the store column and finding the count of unique items in each store


df.groupby(["store"])["item"].nunique()
# Out:
# store
# 1     50
# 2     50
# 3     50
# 4     50
# 5     50
# 6     50
# 7     50
# 8     50
# 9     50
# 10    50
# Name: item, dtype: int64

# %%
# group by 2 coumns and finding sales sum and other parameters like mean median and mode

df.groupby(["store", "item"]).agg({"sales": ["sum", "mean", "median", "std"]})
# Out:
#                sales
#                  sum       mean median        std
# store item
# 1     1      36468.0  19.971522   19.0   6.741022
#       2      97050.0  53.148959   52.0  15.005779
#       3      60638.0  33.208105   33.0  10.072529
#       4      36440.0  19.956188   20.0   6.640618
#       5      30335.0  16.612815   16.0   5.672102
# ...              ...        ...    ...        ...
# 10    46    120601.0  66.046550   65.0  18.114991
#       47     45204.0  24.755750   24.0   7.924820
#       48    105570.0  57.814896   57.0  15.898538
#       49     60317.0  33.032311   32.0  10.091610
#       50    135192.0  74.037240   73.0  19.937566
#
# [500 rows x 4 columns]

# %%
df['month'] = df.date.dt.month

df['day_of_month'] = df.date.dt.day

df['day_of_year'] = df.date.dt.dayofyear 

df['week_of_year'] = df.date.dt.weekofyear

df['day_of_week'] = df.date.dt.dayofweek

df['year'] = df.date.dt.year

df["is_wknd"] = df.date.dt.weekday // 4

df['is_month_start'] = df.date.dt.is_month_start.astype(int)

df['is_month_end'] = df.date.dt.is_month_end.astype(int)

# %%
df.head()
# Out:
#         date  store  item  sales  id  month  day_of_month  day_of_year  week_of_year  day_of_week  year  is_wknd  is_month_start  is_month_end
# 0 2013-01-01      1     1   13.0 NaN      1             1            1             1            1  2013        0               1             0
# 1 2013-01-02      1     1   11.0 NaN      1             2            2             1            2  2013        0               0             0
# 2 2013-01-03      1     1   14.0 NaN      1             3            3             1            3  2013        0               0             0
# 3 2013-01-04      1     1   13.0 NaN      1             4            4             1            4  2013        1               0             0
# 4 2013-01-05      1     1   10.0 NaN      1             5            5             1            5  2013        1               0             0

# %%
df.groupby(["store", "item", "month"]).agg({"sales": ["sum", "mean", "median", "std"]})
# Out:
#                     sales
#                       sum       mean median        std
# store item month
# 1     1    1       2125.0  13.709677   13.0   4.397413
#            2       2063.0  14.631206   14.0   4.668146
#            3       2728.0  17.600000   17.0   4.545013
#            4       3118.0  20.786667   20.0   4.894301
#            5       3448.0  22.245161   22.0   6.564705
# ...                   ...        ...    ...        ...
# 10    50   8      13108.0  84.567742   85.0  15.676527
#            9      11831.0  78.873333   79.0  15.207423
#            10     11322.0  73.045161   72.0  14.209171
#            11     11549.0  76.993333   77.0  16.253651
#            12      8724.0  56.283871   56.0  11.782529
#
# [6000 rows x 4 columns]

# %%
# random noise function 

def random_noise(dataframe):
    return np.random.normal(scale=1.6, size=(len(dataframe),))

# %%
df.sort_values(by=['store', 'item', 'date'], axis=0, inplace=True)
df.head()
# Out:
#         date  store  item  sales  id  month  day_of_month  day_of_year  week_of_year  day_of_week  year  is_wknd  is_month_start  is_month_end
# 0 2013-01-01      1     1   13.0 NaN      1             1            1             1            1  2013        0               1             0
# 1 2013-01-02      1     1   11.0 NaN      1             2            2             1            2  2013        0               0             0
# 2 2013-01-03      1     1   14.0 NaN      1             3            3             1            3  2013        0               0             0
# 3 2013-01-04      1     1   13.0 NaN      1             4            4             1            4  2013        1               0             0
# 4 2013-01-05      1     1   10.0 NaN      1             5            5             1            5  2013        1               0             0

# %%
# lag features function 


def lag_features(dataframe, lags):
    for lag in lags:
        dataframe['sales_lag_' + str(lag)] = dataframe.groupby(["store", "item"])['sales'].transform(
            lambda x: x.shift(lag)) + random_noise(dataframe)
    return dataframe

df = lag_features(df, [91, 98, 105, 112, 119, 126, 182, 364, 546, 728])

# %%
def roll_mean_features(dataframe, windows):
    for window in windows:
        dataframe['sales_roll_mean_' + str(window)] = dataframe.groupby(["store", "item"])['sales']. \
                                                          transform(
            lambda x: x.shift(1).rolling(window=window, min_periods=10, win_type="triang").mean()) + random_noise(
            dataframe)
    return dataframe


df = roll_mean_features(df, [365, 546, 730])

# %%
def ewm_features(dataframe, alphas, lags):
    for alpha in alphas:
        for lag in lags:
            dataframe['sales_ewm_alpha_' + str(alpha).replace(".", "") + "_lag_" + str(lag)] = \
                dataframe.groupby(["store", "item"])['sales'].transform(lambda x: x.shift(lag).ewm(alpha=alpha).mean())
    return dataframe


alphas = [0.99, 0.95, 0.9, 0.8, 0.7, 0.5]
lags = [91, 98, 105, 112, 180, 270, 365, 546, 728]

df = ewm_features(df, alphas, lags)
df.tail()
# Out:
#             date  store  item  sales       id  month  day_of_month  day_of_year  week_of_year  day_of_week  year  is_wknd  is_month_start  is_month_end  sales_lag_91  sales_lag_98  sales_lag_105  sales_lag_112  sales_lag_119  sales_lag_126  sales_lag_182  sales_lag_364  sales_lag_546  sales_lag_728  sales_roll_mean_365  sales_roll_mean_546  sales_roll_mean_730  sales_ewm_alpha_099_lag_91  sales_ewm_alpha_099_lag_98  sales_ewm_alpha_099_lag_105  sales_ewm_alpha_099_lag_112  \
# 44995 2018-03-27     10    50    NaN  44995.0      3            27           86            13            1  2018        0               0             0     43.987591     54.041321      67.364104      71.250998      65.135455      81.034268      81.429771      61.641876      96.159280      71.856642            88.191111            84.436650            83.674209                   41.102494                   53.993266                    66.871500                    67.862074
# 44996 2018-03-28     10    50    NaN  44996.0      3            28           87            13            2  2018        0               0             0     63.655329     51.598878      68.674089      58.680413      75.223641      80.120772      77.832415      70.882179      79.931934      69.434054            87.915962            85.138683            83.246532                   62.781025                   51.029933                    66.998715                    60.078621
# 44997 2018-03-29     10    50    NaN  44997.0      3            29           88            13            3  2018        0               0             0     58.583908     62.993193      71.356259      65.082980      76.027779      89.712883      78.237593      68.200591     100.084219      75.589442            86.774933            87.658461            82.915906                   59.037810                   62.880299                    71.949987                    65.940786
# 44998 2018-03-30     10    50    NaN  44998.0      3            30           89            13            4  2018        1               0             0     75.183464     77.094092      76.340309      66.282856      66.563049      79.456693      88.900400      68.084102      78.216959      83.721144            85.669437            83.736560            83.460692                   73.850378                   74.878803                    71.999500                    66.989408
# 44999 2018-03-31     10    50    NaN  44999.0      3            31           90            13            5  2018        1               0             1     60.860655     71.562285      50.975341      67.809346      46.891764      78.087858     103.132020      99.605608      98.925863      80.796614            87.685957            88.368869            85.355127                   62.118504                   70.048788                    52.199995                    68.979894
#
#        sales_ewm_alpha_099_lag_180  sales_ewm_alpha_099_lag_270  sales_ewm_alpha_099_lag_365  sales_ewm_alpha_099_lag_546  sales_ewm_alpha_099_lag_728  sales_ewm_alpha_095_lag_91  sales_ewm_alpha_095_lag_98  sales_ewm_alpha_095_lag_105  sales_ewm_alpha_095_lag_112  sales_ewm_alpha_095_lag_180  sales_ewm_alpha_095_lag_270  sales_ewm_alpha_095_lag_365  sales_ewm_alpha_095_lag_546  sales_ewm_alpha_095_lag_728  sales_ewm_alpha_09_lag_91  sales_ewm_alpha_09_lag_98  sales_ewm_alpha_09_lag_105  \
# 44995                    81.979884                   112.096892                    66.149794                    96.496783                    72.783196                   41.561777                   54.028375                    66.387487                    67.349358                    81.895724                   112.421502                    66.744209                    94.617783                    71.979468                  42.244368                  54.197995                   65.849785
# 44996                    89.919799                   118.930969                    60.061498                    80.164968                    68.047832                   61.928089                   51.151419                    66.969374                    60.367468                    89.594786                   118.671075                    60.337210                    80.730889                    68.198973                  60.924437                  51.319799                   66.884978
# 44997                   102.869198                   119.989310                    72.870615                    98.811650                    74.930478                   59.146404                   62.407571                    71.748469                    65.718373                   102.329739                   119.933554                    72.366861                    98.086544                    74.659949                  59.192444                  61.831980                   71.488498
# 44998                    99.038692                    99.209893                    68.048706                    79.198116                    82.919305                   73.257320                   74.370379                    71.987423                    66.935919                    99.166487                   100.046678                    68.218343                    79.954327                    82.582997                  72.519244                  73.683198                   71.948850
# 44999                    71.280387                    98.012099                    68.990487                    96.821981                    82.009193                   62.562866                   70.218519                    52.999371                    68.896796                    72.408324                    98.102334                    68.960917                    96.147716                    82.029150                  63.051924                  70.368320                   53.994885
#
#        sales_ewm_alpha_09_lag_112  sales_ewm_alpha_09_lag_180  sales_ewm_alpha_09_lag_270  sales_ewm_alpha_09_lag_365  sales_ewm_alpha_09_lag_546  sales_ewm_alpha_09_lag_728  sales_ewm_alpha_08_lag_91  sales_ewm_alpha_08_lag_98  sales_ewm_alpha_08_lag_105  sales_ewm_alpha_08_lag_112  sales_ewm_alpha_08_lag_180  sales_ewm_alpha_08_lag_270  sales_ewm_alpha_08_lag_365  sales_ewm_alpha_08_lag_546  sales_ewm_alpha_08_lag_728  sales_ewm_alpha_07_lag_91  sales_ewm_alpha_07_lag_98  \
# 44995                   66.785772                   81.777579                  112.682169                   67.473304                   92.561560                   71.115472                  43.955442                  54.879654                   64.996171                   65.861563                   81.488819                  112.703381                   68.859556                   89.361543                   69.838571                  46.091666                  55.909793
# 44996                   60.678577                   89.177758                  118.368217                   60.747330                   81.256156                   68.311547                  59.191088                  51.775931                   66.599234                   61.172313                   88.297764                  117.740676                   61.771911                   81.872309                   68.367714                  57.927500                  52.472938
# 44997                   65.467858                  101.617776                  119.836822                   71.774733                   97.225616                   74.331155                  59.038218                  60.755186                   70.919847                   65.034463                  100.059553                  119.548135                   70.754382                   95.574462                   73.673543                  58.678250                  59.841881
# 44998                   66.846786                   99.261778                  101.083682                   68.377473                   80.822562                   82.133115                  71.007644                  72.151037                   71.783969                   66.606893                   99.211911                  103.109627                   68.550876                   82.314892                   81.134709                  69.403475                  70.452564
# 44999                   68.784679                   73.826178                   98.308368                   68.937747                   95.382256                   82.013312                  63.801529                  70.430207                   55.956794                   68.521379                   76.642382                   99.021925                   68.910175                   94.062978                   81.826942                  64.221042                  70.135769
#
#        sales_ewm_alpha_07_lag_105  sales_ewm_alpha_07_lag_112  sales_ewm_alpha_07_lag_180  sales_ewm_alpha_07_lag_270  sales_ewm_alpha_07_lag_365  sales_ewm_alpha_07_lag_546  sales_ewm_alpha_07_lag_728  sales_ewm_alpha_05_lag_91  sales_ewm_alpha_05_lag_98  sales_ewm_alpha_05_lag_105  sales_ewm_alpha_05_lag_112  sales_ewm_alpha_05_lag_180  sales_ewm_alpha_05_lag_270  sales_ewm_alpha_05_lag_365  sales_ewm_alpha_05_lag_546  sales_ewm_alpha_05_lag_728
# 44995                   64.428121                   65.144155                   81.162051                  112.055216                   70.090358                   87.248414                   69.116907                  51.309755                  58.648702                   64.033868                   64.335072                   80.828687                  109.036310                   71.734958                   85.489012                   68.933911
# 44996                   66.228436                   61.543247                   87.348615                  116.916565                   63.027108                   82.174524                   68.335072                  57.154878                  54.824351                   65.516934                   62.167536                   85.414343                  114.018155                   65.867479                   82.744506                   68.466956
# 44997                   70.268531                   64.662974                   98.304585                  119.074969                   70.008132                   93.952357                   73.000522                  58.077439                  58.912176                   68.758467                   64.083768                   94.207172                  117.009078                   69.433740                   90.872253                   71.733478
# 44998                   71.480559                   66.298892                   98.791375                  105.022491                   68.602440                   83.485707                   80.000156                  66.038719                  66.956088                   70.379233                   65.541884                   96.603586                  108.004539                   68.716870                   84.936127                   77.366739
# 44999                   57.844168                   68.189668                   79.337413                  100.106747                   68.880732                   92.945712                   81.400047                  64.019360                  68.478044                   61.189617                   67.270942                   83.801793                  103.002269                   68.858435                   90.968063                   79.683369

# %%
df = pd.get_dummies(df, columns=['day_of_week', 'month'])

# %%
df['sales'] = np.log1p(df["sales"].values)

# %%
train = df.loc[(df["date"] < "2017-01-01"), :]


val = df.loc[(df["date"] >= "2017-01-01") & (df["date"] < "2017-04-01"), :]


cols = [col for col in train.columns if col not in ['date', 'id', "sales", "year"]]

# %%
Y_train = train['sales']


X_train = train[cols]


Y_val = val['sales']


X_val = val[cols] 


Y_train.shape, X_train.shape, Y_val.shape, X_val.shape
# Out:
# ((730500,), (730500, 94), (45000,), (45000, 94))

# %%
def smape(preds, target):
    n = len(preds)
    masked_arr = ~((preds == 0) & (target == 0))
    preds, target = preds[masked_arr], target[masked_arr]
    num = np.abs(preds - target)
    denom = np.abs(preds) + np.abs(target)
    smape_val = (200 * np.sum(num / denom)) / n
    return smape_val


def lgbm_smape(preds, train_data):
    labels = train_data.get_label()
    smape_val = smape(np.expm1(preds), np.expm1(labels))
    return 'SMAPE', smape_val, False

# %%
lgb_params = {'metric': {'mae'},
              'num_leaves': 10,
              'learning_rate': 0.02,
              'feature_fraction': 0.8,
              'max_depth': 5,
              'verbose': 0,
              'num_boost_round': 10000, 
              'early_stopping_rounds': 200,
              'nthread': -1}

# %%
lgbtrain = lgb.Dataset(data=X_train, label=Y_train, feature_name=cols)
lgbval = lgb.Dataset(data=X_val, label=Y_val, reference=lgbtrain, feature_name=cols)

model = lgb.train(lgb_params, lgbtrain,
                  valid_sets=[lgbtrain, lgbval],
                  num_boost_round=lgb_params['num_boost_round'],
                  early_stopping_rounds=lgb_params['early_stopping_rounds'],
                  feval=lgbm_smape, 
                  verbose_eval=100)

y_pred_val = model.predict(X_val, num_iteration=model.best_iteration)


smape(np.expm1(y_pred_val), np.expm1(Y_val))
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.405417 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# Training until validation scores don't improve for 200 rounds
# [100]	training's l1: 0.171645	training's SMAPE: 17.5062	valid_1's l1: 0.171065	valid_1's SMAPE: 17.4839
# [200]	training's l1: 0.141362	training's SMAPE: 14.4792	valid_1's l1: 0.144941	valid_1's SMAPE: 14.8686
# [300]	training's l1: 0.135773	training's SMAPE: 13.9193	valid_1's l1: 0.140072	valid_1's SMAPE: 14.3804
# [400]	training's l1: 0.133666	training's SMAPE: 13.7086	valid_1's l1: 0.138431	valid_1's SMAPE: 14.2161
# [500]	training's l1: 0.132471	training's SMAPE: 13.5889	valid_1's l1: 0.137171	valid_1's SMAPE: 14.0895
# [600]	training's l1: 0.131629	training's SMAPE: 13.5043	valid_1's l1: 0.136105	valid_1's SMAPE: 13.9822
# [700]	training's l1: 0.131017	training's SMAPE: 13.443	valid_1's l1: 0.135383	valid_1's SMAPE: 13.9096
# [800]	training's l1: 0.130538	training's SMAPE: 13.395	valid_1's l1: 0.134802	valid_1's SMAPE: 13.8511
# [900]	training's l1: 0.130138	training's SMAPE: 13.3549	valid_1's l1: 0.134391	valid_1's SMAPE: 13.8096
# [1000]	training's l1: 0.129799	training's SMAPE: 13.321	valid_1's l1: 0.13408	valid_1's SMAPE: 13.7783
# [1100]	training's l1: 0.129515	training's SMAPE: 13.2926	valid_1's l1: 0.133782	valid_1's SMAPE: 13.7483
# [1200]	training's l1: 0.129257	training's SMAPE: 13.2668	valid_1's l1: 0.133568	valid_1's SMAPE: 13.7267
# [1300]	training's l1: 0.129026	training's SMAPE: 13.2438	valid_1's l1: 0.133376	valid_1's SMAPE: 13.7073
# [1400]	training's l1: 0.128833	training's SMAPE: 13.2244	valid_1's l1: 0.133206	valid_1's SMAPE: 13.6903
# [1500]	training's l1: 0.128641	training's SMAPE: 13.2053	valid_1's l1: 0.133066	valid_1's SMAPE: 13.6761
# [1600]	training's l1: 0.128482	training's SMAPE: 13.1894	valid_1's l1: 0.132924	valid_1's SMAPE: 13.6618
# [1700]	training's l1: 0.128336	training's SMAPE: 13.1747	valid_1's l1: 0.132802	valid_1's SMAPE: 13.6495
# [1800]	training's l1: 0.128207	training's SMAPE: 13.1618	valid_1's l1: 0.132687	valid_1's SMAPE: 13.638
# [1900]	training's l1: 0.128085	training's SMAPE: 13.1496	valid_1's l1: 0.132596	valid_1's SMAPE: 13.6288
# [2000]	training's l1: 0.127971	training's SMAPE: 13.1381	valid_1's l1: 0.132518	valid_1's SMAPE: 13.6209
# [2100]	training's l1: 0.127864	training's SMAPE: 13.1273	valid_1's l1: 0.132438	valid_1's SMAPE: 13.6129
# [2200]	training's l1: 0.127765	training's SMAPE: 13.1173	valid_1's l1: 0.132373	valid_1's SMAPE: 13.6063
# [2300]	training's l1: 0.12767	training's SMAPE: 13.1079	valid_1's l1: 0.132304	valid_1's SMAPE: 13.5994
# [2400]	training's l1: 0.127565	training's SMAPE: 13.0974	valid_1's l1: 0.132245	valid_1's SMAPE: 13.5934
# [2500]	training's l1: 0.127487	training's SMAPE: 13.0895	valid_1's l1: 0.132195	valid_1's SMAPE: 13.5883
# [2600]	training's l1: 0.127412	training's SMAPE: 13.0819	valid_1's l1: 0.132157	valid_1's SMAPE: 13.5846
# [2700]	training's l1: 0.127335	training's SMAPE: 13.0741	valid_1's l1: 0.132112	valid_1's SMAPE: 13.58
# [2800]	training's l1: 0.12726	training's SMAPE: 13.0667	valid_1's l1: 0.13207	valid_1's SMAPE: 13.5758
# [2900]	training's l1: 0.127184	training's SMAPE: 13.059	valid_1's l1: 0.132014	valid_1's SMAPE: 13.5702
# [3000]	training's l1: 0.127118	training's SMAPE: 13.0524	valid_1's l1: 0.13198	valid_1's SMAPE: 13.5667
# [3100]	training's l1: 0.127054	training's SMAPE: 13.0459	valid_1's l1: 0.131954	valid_1's SMAPE: 13.5641
# [3200]	training's l1: 0.126994	training's SMAPE: 13.0399	valid_1's l1: 0.131911	valid_1's SMAPE: 13.5598
# [3300]	training's l1: 0.12693	training's SMAPE: 13.0334	valid_1's l1: 0.131884	valid_1's SMAPE: 13.557
# [3400]	training's l1: 0.126873	training's SMAPE: 13.0277	valid_1's l1: 0.13184	valid_1's SMAPE: 13.5526
# [3500]	training's l1: 0.126818	training's SMAPE: 13.0221	valid_1's l1: 0.131816	valid_1's SMAPE: 13.5502
# [3600]	training's l1: 0.126758	training's SMAPE: 13.016	valid_1's l1: 0.13179	valid_1's SMAPE: 13.5476
# [3700]	training's l1: 0.1267	training's SMAPE: 13.0102	valid_1's l1: 0.131763	valid_1's SMAPE: 13.5449
# [3800]	training's l1: 0.126649	training's SMAPE: 13.0051	valid_1's l1: 0.131735	valid_1's SMAPE: 13.542
# [3900]	training's l1: 0.1266	training's SMAPE: 13.0001	valid_1's l1: 0.131703	valid_1's SMAPE: 13.5388
# [4000]	training's l1: 0.126552	training's SMAPE: 12.9951	valid_1's l1: 0.131679	valid_1's SMAPE: 13.5364
# [4100]	training's l1: 0.126493	training's SMAPE: 12.9893	valid_1's l1: 0.131659	valid_1's SMAPE: 13.5344
# [4200]	training's l1: 0.126445	training's SMAPE: 12.9844	valid_1's l1: 0.13164	valid_1's SMAPE: 13.5326
# [4300]	training's l1: 0.1264	training's SMAPE: 12.9799	valid_1's l1: 0.131619	valid_1's SMAPE: 13.5304
# [4400]	training's l1: 0.126355	training's SMAPE: 12.9753	valid_1's l1: 0.131593	valid_1's SMAPE: 13.5278
# [4500]	training's l1: 0.126309	training's SMAPE: 12.9706	valid_1's l1: 0.131574	valid_1's SMAPE: 13.5259
# [4600]	training's l1: 0.126262	training's SMAPE: 12.9658	valid_1's l1: 0.131559	valid_1's SMAPE: 13.5244
# [4700]	training's l1: 0.126217	training's SMAPE: 12.9613	valid_1's l1: 0.131544	valid_1's SMAPE: 13.5228
# [4800]	training's l1: 0.126172	training's SMAPE: 12.9567	valid_1's l1: 0.131525	valid_1's SMAPE: 13.5209
# [4900]	training's l1: 0.126132	training's SMAPE: 12.9526	valid_1's l1: 0.131506	valid_1's SMAPE: 13.5191
# [5000]	training's l1: 0.126085	training's SMAPE: 12.9478	valid_1's l1: 0.131493	valid_1's SMAPE: 13.5178
# [5100]	training's l1: 0.126043	training's SMAPE: 12.9436	valid_1's l1: 0.13147	valid_1's SMAPE: 13.5155
# [5200]	training's l1: 0.126004	training's SMAPE: 12.9397	valid_1's l1: 0.13146	valid_1's SMAPE: 13.5145
# [5300]	training's l1: 0.125962	training's SMAPE: 12.9354	valid_1's l1: 0.131441	valid_1's SMAPE: 13.5125
# [5400]	training's l1: 0.125917	training's SMAPE: 12.9308	valid_1's l1: 0.131423	valid_1's SMAPE: 13.5108
# [5500]	training's l1: 0.125879	training's SMAPE: 12.9269	valid_1's l1: 0.131412	valid_1's SMAPE: 13.5097
# [5600]	training's l1: 0.125837	training's SMAPE: 12.9228	valid_1's l1: 0.131398	valid_1's SMAPE: 13.5082
# [5700]	training's l1: 0.125797	training's SMAPE: 12.9187	valid_1's l1: 0.131385	valid_1's SMAPE: 13.5069
# [5800]	training's l1: 0.125752	training's SMAPE: 12.9141	valid_1's l1: 0.131366	valid_1's SMAPE: 13.505
# [5900]	training's l1: 0.125717	training's SMAPE: 12.9105	valid_1's l1: 0.131356	valid_1's SMAPE: 13.504
# [6000]	training's l1: 0.125675	training's SMAPE: 12.9063	valid_1's l1: 0.131341	valid_1's SMAPE: 13.5025
# [6100]	training's l1: 0.125639	training's SMAPE: 12.9026	valid_1's l1: 0.131337	valid_1's SMAPE: 13.5021
# [6200]	training's l1: 0.1256	training's SMAPE: 12.8987	valid_1's l1: 0.131329	valid_1's SMAPE: 13.5013
# [6300]	training's l1: 0.125562	training's SMAPE: 12.8948	valid_1's l1: 0.131314	valid_1's SMAPE: 13.4997
# [6400]	training's l1: 0.125526	training's SMAPE: 12.8912	valid_1's l1: 0.131305	valid_1's SMAPE: 13.4989
# [6500]	training's l1: 0.12549	training's SMAPE: 12.8875	valid_1's l1: 0.131296	valid_1's SMAPE: 13.498
# [6600]	training's l1: 0.125454	training's SMAPE: 12.8838	valid_1's l1: 0.131288	valid_1's SMAPE: 13.4972
# [6700]	training's l1: 0.125418	training's SMAPE: 12.8802	valid_1's l1: 0.13128	valid_1's SMAPE: 13.4964
# [6800]	training's l1: 0.125381	training's SMAPE: 12.8764	valid_1's l1: 0.131265	valid_1's SMAPE: 13.4948
# [6900]	training's l1: 0.125349	training's SMAPE: 12.8731	valid_1's l1: 0.131264	valid_1's SMAPE: 13.4947
# [7000]	training's l1: 0.125316	training's SMAPE: 12.8698	valid_1's l1: 0.131253	valid_1's SMAPE: 13.4936
# [7100]	training's l1: 0.125284	training's SMAPE: 12.8666	valid_1's l1: 0.131246	valid_1's SMAPE: 13.4929
# [7200]	training's l1: 0.125252	training's SMAPE: 12.8633	valid_1's l1: 0.13124	valid_1's SMAPE: 13.4924
# [7300]	training's l1: 0.125215	training's SMAPE: 12.8595	valid_1's l1: 0.131229	valid_1's SMAPE: 13.4912
# [7400]	training's l1: 0.125179	training's SMAPE: 12.8558	valid_1's l1: 0.131226	valid_1's SMAPE: 13.4909
# [7500]	training's l1: 0.125142	training's SMAPE: 12.8521	valid_1's l1: 0.131217	valid_1's SMAPE: 13.49
# [7600]	training's l1: 0.125107	training's SMAPE: 12.8486	valid_1's l1: 0.131212	valid_1's SMAPE: 13.4896
# [7700]	training's l1: 0.125075	training's SMAPE: 12.8453	valid_1's l1: 0.131206	valid_1's SMAPE: 13.4889
# [7800]	training's l1: 0.125045	training's SMAPE: 12.8422	valid_1's l1: 0.131201	valid_1's SMAPE: 13.4885
# [7900]	training's l1: 0.125013	training's SMAPE: 12.839	valid_1's l1: 0.131196	valid_1's SMAPE: 13.488
# [8000]	training's l1: 0.124982	training's SMAPE: 12.8358	valid_1's l1: 0.131193	valid_1's SMAPE: 13.4877
# [8100]	training's l1: 0.124952	training's SMAPE: 12.8327	valid_1's l1: 0.131187	valid_1's SMAPE: 13.4871
# [8200]	training's l1: 0.124923	training's SMAPE: 12.8298	valid_1's l1: 0.131183	valid_1's SMAPE: 13.4867
# [8300]	training's l1: 0.124892	training's SMAPE: 12.8267	valid_1's l1: 0.131177	valid_1's SMAPE: 13.4861
# [8400]	training's l1: 0.124855	training's SMAPE: 12.823	valid_1's l1: 0.131168	valid_1's SMAPE: 13.4852
# [8500]	training's l1: 0.124826	training's SMAPE: 12.8199	valid_1's l1: 0.131164	valid_1's SMAPE: 13.4848
# [8600]	training's l1: 0.124794	training's SMAPE: 12.8167	valid_1's l1: 0.131161	valid_1's SMAPE: 13.4845
# [8700]	training's l1: 0.124764	training's SMAPE: 12.8136	valid_1's l1: 0.131153	valid_1's SMAPE: 13.4837
# [8800]	training's l1: 0.124735	training's SMAPE: 12.8108	valid_1's l1: 0.131149	valid_1's SMAPE: 13.4833
# [8900]	training's l1: 0.124701	training's SMAPE: 12.8073	valid_1's l1: 0.131149	valid_1's SMAPE: 13.4833
# [9000]	training's l1: 0.124672	training's SMAPE: 12.8043	valid_1's l1: 0.131145	valid_1's SMAPE: 13.483
# [9100]	training's l1: 0.124643	training's SMAPE: 12.8014	valid_1's l1: 0.131143	valid_1's SMAPE: 13.4828
# [9200]	training's l1: 0.124613	training's SMAPE: 12.7983	valid_1's l1: 0.13114	valid_1's SMAPE: 13.4825
# [9300]	training's l1: 0.124581	training's SMAPE: 12.795	valid_1's l1: 0.131138	valid_1's SMAPE: 13.4823
# [9400]	training's l1: 0.124552	training's SMAPE: 12.7921	valid_1's l1: 0.13113	valid_1's SMAPE: 13.4815
# [9500]	training's l1: 0.124521	training's SMAPE: 12.7889	valid_1's l1: 0.131128	valid_1's SMAPE: 13.4812
# [9600]	training's l1: 0.124491	training's SMAPE: 12.7859	valid_1's l1: 0.131123	valid_1's SMAPE: 13.4808
# [9700]	training's l1: 0.124465	training's SMAPE: 12.7832	valid_1's l1: 0.13112	valid_1's SMAPE: 13.4805
# [9800]	training's l1: 0.124438	training's SMAPE: 12.7805	valid_1's l1: 0.131117	valid_1's SMAPE: 13.4802
# [9900]	training's l1: 0.124408	training's SMAPE: 12.7774	valid_1's l1: 0.131118	valid_1's SMAPE: 13.4803
# [10000]	training's l1: 0.12438	training's SMAPE: 12.7746	valid_1's l1: 0.131113	valid_1's SMAPE: 13.4798
# Did not meet early stopping. Best iteration is:
# [10000]	training's l1: 0.12438	training's SMAPE: 12.7746	valid_1's l1: 0.131113	valid_1's SMAPE: 13.4798
# 13.479785459814321

# %%
#Final Model



train = df.loc[~df.sales.isna()]
Y_train = train['sales']
X_train = train[cols]

test = df.loc[df.sales.isna()]
X_test = test[cols]

# %%
lgb_params = {'metric': {'mae'},
              'num_leaves': 10,
              'learning_rate': 0.02,
              'feature_fraction': 0.8,
              'max_depth': 5,
              'verbose': 0,
              'nthread': -1,
              "num_boost_round": model.best_iteration}

# LightGBM dataset

lgbtrain_all = lgb.Dataset(data=X_train, label=Y_train, feature_name=cols)

model = lgb.train(lgb_params, lgbtrain_all, num_boost_round=model.best_iteration)
test_preds = model.predict(X_test, num_iteration=model.best_iteration)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.597284 seconds.
# You can set `force_col_wise=true` to remove the overhead.

# %%
forecast = pd.DataFrame({"date":test["date"],
                        "store":test["store"],
                        "item":test["item"],
                        "sales":test_preds
                        })

forecast[(forecast.store == 1) & (forecast.item == 1)].set_index("date").sales.plot(color = "green",
                                                                                    figsize = (20,9),
                                                                                    legend=True, label = "Store 1 Item 1 Forecast");

# %%
train[(train.store == 1) & (train.item == 17)].set_index("date").sales.plot(figsize = (20,9),legend=True, label = "Store 1 Item 17 Sales")
forecast[(forecast.store == 1) & (forecast.item == 17)].set_index("date").sales.plot(legend=True, label = "Store 1 Item 17 Forecast");

# %%
df.shape
# Out:
# (958000, 98)

# %%
forecast
# Out:
#             date  store  item     sales
# 0     2018-01-01      1     1  2.550876
# 1     2018-01-02      1     1  2.698721
# 2     2018-01-03      1     1  2.742500
# 3     2018-01-04      1     1  2.786334
# 4     2018-01-05      1     1  2.879532
# ...          ...    ...   ...       ...
# 44995 2018-03-27     10    50  4.293063
# 44996 2018-03-28     10    50  4.328467
# 44997 2018-03-29     10    50  4.385248
# 44998 2018-03-30     10    50  4.433065
# 44999 2018-03-31     10    50  4.469459
#
# [45000 rows x 4 columns]
